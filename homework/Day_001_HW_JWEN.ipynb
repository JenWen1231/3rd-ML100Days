# %%
#1.1

import numpy as np
import matplotlib.pyplot as plt
import math
def mean_absolute_error(y,yp):
    mae=MAE=(sum(abs(y-yp)))/len(y)
    return mae

def mean_square_error(y,yp):
    mse=MSE=sum((math.pow((y-yp),2))/len(y)
    return mse
w=3
b=0.5
x_lin=np.linspace(0,100,101)
y=(x_lin+np.random.randn(101)*5)*w+b
y_hat=x_lin*w+b

plt.plot(x_lin,y,'b.',label='data points')
plt.plot(x_lin,y_hat,'r-',label='prediction')
plt.title('Assume we have data points and prediction')
plt.legend(loc=2)
plt.show()

MAE=mean_absolute_error(y,y_hat)
MSE=mean_square_error(y,y_hat)

print('The mean absolute error is %.3f' %(MAE))
print('The mean square error is %.3f' %(MSE))
# Out:
# The mean absolute error is 12.599
# The mean square error is 15901.394

# %%
#1.2
"""

你選的這組資料為何重要 : to support people how to choose a good book

資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集): Goodreads-books comprehensive list of all books listed in goodreads by Soumik. This data was entirely scraped via the Goodreads API, so kudos to them for providing such a simple interface to scrape their database.

蒐集而來的資料型態為何: structural data in CSV

這組資料想解決的問題如何評估: to find out what kinds of books are good for consumers. ROC can be used.
"""
# Out:
# '\n\n你選的這組資料為何重要\n\n資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)\n\n蒐集而來的資料型態為何\n\n這組資料想解決的問題如何評估\n'

# %%
#1.3
"""
核心問題為何 (tips：如何定義 「提升業績 & 你的假設」) how to increase weekly income. If next week income can be higher than previous week. It means the target is met.

資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集) from collecting data of daily orders, completed orders, distination

蒐集而來的資料型態為何 structural data

你要回答的問題，其如何評估 (tips：你的假設如何驗證) if income will be closed to max estimation amount.
"""
